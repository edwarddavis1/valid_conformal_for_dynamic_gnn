# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# ## Experiment parameters

# %%
# Number of time windows
T = 30

# Target 1-coverage for conformal prediction
alpha = 0.1

# %% [markdown]
# ## Load results

# %%
results_file = 'results/Conformal_GNN_Trade_Results.pkl'

with open(results_file, 'rb') as file:
    results = pickle.load(file)

# %% [markdown]
# Save figures into a special folder.

# %%
save_figs = False
output_file_prefix = 'figures/Trade_'
output_file_suffix = '_10_100_50.pdf'

# %% [markdown]
# ## Summary results

# %%
methods = ['BD', 'UA']
GNN_models = ['GCN', 'GAT']
regimes = ['Trans', 'Semi-Ind']
outputs = ['Accuracy', 'Avg Size', 'Coverage']

# %%
methods_list = []
GNN_models_list = []
regimes_list = []
outputs_list = []
stat_types_list = []
stats_list = []

for (method, GNN_model, regime, output) in product(methods, GNN_models, regimes, outputs):
    methods_list.append(method)
    GNN_models_list.append(GNN_model)
    regimes_list.append(regime)
    outputs_list.append(output)
    stat_types_list.append('Mean')
    stats_list.append(np.round(np.mean(results[method][GNN_model][regime][output]['All']), 3))
    
    methods_list.append(method)
    GNN_models_list.append(GNN_model)
    regimes_list.append(regime)
    outputs_list.append(output)
    stat_types_list.append('St Dev')
    stats_list.append(np.round(np.std(results[method][GNN_model][regime][output]['All']), 3))
    
df_summary = pd.DataFrame({
    'method'   : methods_list,
    'GNN model': GNN_models_list,
    'regime'   : regimes_list,
    'output'   : outputs_list,
    'statistic': stat_types_list,
    'value'    : stats_list
})

# %% [markdown]
# Display full table of statistics.

# %%
print(df_summary)
# Out:
#    method GNN model    regime    output statistic   value
# 0      BD       GCN     Trans  Accuracy      Mean   0.095
# 1      BD       GCN     Trans  Accuracy    St Dev   0.017
# 2      BD       GCN     Trans  Avg Size      Mean  82.556
# 3      BD       GCN     Trans  Avg Size    St Dev   4.966
# 4      BD       GCN     Trans  Coverage      Mean   0.900
# 5      BD       GCN     Trans  Coverage    St Dev   0.009
# 6      BD       GCN  Semi-Ind  Accuracy      Mean   0.049
# 7      BD       GCN  Semi-Ind  Accuracy    St Dev   0.018
# 8      BD       GCN  Semi-Ind  Avg Size      Mean  80.652
# 9      BD       GCN  Semi-Ind  Avg Size    St Dev   6.709
# 10     BD       GCN  Semi-Ind  Coverage      Mean   0.842
# 11     BD       GCN  Semi-Ind  Coverage    St Dev   0.015
# 12     BD       GAT     Trans  Accuracy      Mean   0.125
# 13     BD       GAT     Trans  Accuracy    St Dev   0.017
# 14     BD       GAT     Trans  Avg Size      Mean  87.603
# 15     BD       GAT     Trans  Avg Size    St Dev   6.945
# 16     BD       GAT     Trans  Coverage      Mean   0.900
# 17     BD       GAT     Trans  Coverage    St Dev   0.009
# 18     BD       GAT  Semi-Ind  Accuracy      Mean   0.046
# 19     BD       GAT  Semi-Ind  Accuracy    St Dev   0.015
# 20     BD       GAT  Semi-Ind  Avg Size      Mean  84.708
# 21     BD       GAT  Semi-Ind  Avg Size    St Dev   9.690
# 22     BD       GAT  Semi-Ind  Coverage      Mean   0.840
# 23     BD       GAT  Semi-Ind  Coverage    St Dev   0.021
# 24     UA       GCN     Trans  Accuracy      Mean   0.082
# 25     UA       GCN     Trans  Accuracy    St Dev   0.031
# 26     UA       GCN     Trans  Avg Size      Mean  86.319
# 27     UA       GCN     Trans  Avg Size    St Dev   7.520
# 28     UA       GCN     Trans  Coverage      Mean   0.900
# 29     UA       GCN     Trans  Coverage    St Dev   0.009
# 30     UA       GCN  Semi-Ind  Accuracy      Mean   0.050
# 31     UA       GCN  Semi-Ind  Accuracy    St Dev   0.017
# 32     UA       GCN  Semi-Ind  Avg Size      Mean  85.006
# 33     UA       GCN  Semi-Ind  Avg Size    St Dev   9.516
# 34     UA       GCN  Semi-Ind  Coverage      Mean   0.847
# 35     UA       GCN  Semi-Ind  Coverage    St Dev   0.017
# 36     UA       GAT     Trans  Accuracy      Mean   0.111
# 37     UA       GAT     Trans  Accuracy    St Dev   0.010
# 38     UA       GAT     Trans  Avg Size      Mean  92.200
# 39     UA       GAT     Trans  Avg Size    St Dev   7.364
# 40     UA       GAT     Trans  Coverage      Mean   0.901
# 41     UA       GAT     Trans  Coverage    St Dev   0.009
# 42     UA       GAT  Semi-Ind  Accuracy      Mean   0.048
# 43     UA       GAT  Semi-Ind  Accuracy    St Dev   0.015
# 44     UA       GAT  Semi-Ind  Avg Size      Mean  90.021
# 45     UA       GAT  Semi-Ind  Avg Size    St Dev  11.592
# 46     UA       GAT  Semi-Ind  Coverage      Mean   0.854
# 47     UA       GAT  Semi-Ind  Coverage    St Dev   0.023

# %% [markdown]
# ## Plot results

# %%
for (regime, output) in product(regimes, outputs):
    if output == 'Accuracy':
        output_str = 'Accuracy'
    if output == 'Avg Size':
        output_str = 'Prediction Set Size'
    if output == 'Coverage':
        output_str = 'Coverage'

    for GNN_model in GNN_models:
        fig, ax = plt.subplots(1, 1, figsize=(6.0, 3.0))
    
        T_output = np.where(np.array([len(results['BD'][GNN_model][regime][output][t]) for t in range(T)]) > 0)[0]

        output_time_mean = [np.mean(results['BD'][GNN_model][regime][output][t]) for t in T_output]
        output_time_std = [np.std(results['BD'][GNN_model][regime][output][t]) for t in T_output]
        
        if output == 'Coverage':
            ax.axhline(1 - alpha, color='grey', linestyle='--', zorder=1)
        
        ax.errorbar(T_output, output_time_mean, output_time_std, marker='o', capsize=5, ls='None',
                    label='Block Diagonal', zorder=2)
    
        output_time_mean = [np.mean(results['UA'][GNN_model][regime][output][t]) for t in T_output]
        output_time_std = [np.std(results['UA'][GNN_model][regime][output][t]) for t in T_output]

        ax.errorbar(T_output, output_time_mean, output_time_std, marker='o', capsize=5, ls='None',
                    label='Unfolded', zorder=3)
    
        ax.legend()
        
        ax.set_title(GNN_model + ' ' + output_str)
        ax.set_xlabel('Time Window')
        ax.set_ylabel(output_str)
        
        if save_figs:
            fig.savefig(output_file_prefix + regime + '_' + GNN_model + '_' + output + output_file_suffix,
                        bbox_inches='tight');
